# %% [markdown]
# #### **LSTM for next word predictions**
#
# `Thanos` is a an iconic Marvel villian who brought Earth's mightiest herous, `the Avengers` to their knees when he wiped out half of the population to correct what he terms as a resource imbalance and lack of gratitude. Thanos has some pretty iconic quotes that we will try and train a model to recreate.

# %% [markdown]
# **Dependencies**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense,Dropout, Bidirectional, Embedding
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.text import Tokenizer
from nltk.tokenize import sent_tokenize
import numpy as np

# %% [markdown]
# **Data Import and Model Building**
#
# We will use a collcetion of the most famous Thanos quotes as a our corpus, pre-process and generate skipgrams to use as input output pairs for our model.

# %%
file_path = r"C:\Documents\Thanos quotes.txt"

# %%
text = []
for i in range(200):
    with open(file=file_path) as file:
        for line in file:
            if line.startswith("Thanos"):
                continue
            text.append(line.strip())

# %%
corpus = " ".join(text)

# %%
sents = sent_tokenize(corpus)
sents
# Out:
# ['- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  '- "I donâ€™t even know who you are."',
#  '- "Your planet was on the brink of collapse.',
#  'Iâ€™m the one who stopped that.',
#  'Youâ€™re welcome."',
#  '- "Youâ€™re not the only one cursed with knowledge."',
#  '- "The work is done.',
#  'I won.',
#  'What Iâ€™m about to do, Iâ€™m going to enjoy it very, very much."',
#  '- "Fun isnâ€™t something one considers when balancing the universe.',
#  'But thisâ€¦ does put a smile on my face."',
#  '- "Dread it.',
#  'Run from it.',
#  'Destiny arrives all the same."',
#  '- "The hardest choices require the strongest wills."',
#  '- "Youâ€™re strong.',
#  'But I could snap my fingers, and youâ€™d all cease to exist."',
#  '- "Perfectly balanced, as all things should be."',
#  '- "Reality is often disappointing."',
#  '- "In time, you will know what itâ€™s like to lose, to feel so desperately that youâ€™re right, yet to fail all the same."',
#  '- "I ignored my destiny once.',
#  'I cannot do that again."',
#  '- "A small price to pay for salvation."',
#  '- "I hope they remember you."',
#  '- "I am inevitable."',
#  '- "You could not live with your own failure.',
#  'And where did that bring you?',
#  'Back to me."',
#  '- "I will shred this universe down to its last atom and create a new one, a grateful universe."',
#  ...]

# %%
tokenizer = Tokenizer(num_words=200,filters='""-.\n')
tokenizer.fit_on_texts(sents)

# %%
seqs = tokenizer.texts_to_sequences(sents)

# %%
max_len = max([len(i) for i in seqs])

# %% [markdown]
# **Generating inputs and outputs**

# %%
Xs, ys = [], []
window_size = 2

for seq in seqs:
    for i in range(len(seq) - window_size):
        if i+1<len(seq):
            Xs.append(seq[i:i+window_size])
            ys.append(seq[i+window_size])

# %%
vocab_size = len(tokenizer.word_index.values()) + 1

# %%
X = np.array(Xs)
y = np.array(ys)

# %% [markdown]
# **Building the neural network**

# %%
model = Sequential([
    Embedding(vocab_size,output_dim=256,),
    Bidirectional(LSTM(128,return_sequences=True)),
    Dropout(0.2),
    LSTM(100),
    Dense(64,activation='relu',kernel_regularizer=l2(0.01)),
    Dense(vocab_size,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X,y,epochs=50)
# Out:
# Epoch 1/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.5912 - loss: 2.4225
# Epoch 2/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 0.1982
# Epoch 3/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 1.0000 - loss: 0.1092
# Epoch 4/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 1.0000 - loss: 0.0708
# Epoch 5/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 1.0000 - loss: 0.0490
# Epoch 6/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 0.0353
# Epoch 7/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 8/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 1.0000 - loss: 0.0220
# Epoch 9/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 1.0000 - loss: 0.0183
# Epoch 10/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 11/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 12/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 13/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 14/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 15/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 16/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 17/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 18/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 19/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 20/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 21/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 22/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 23/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 24/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 25/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.9991 - loss: 0.0207
# Epoch 26/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 27/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 28/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 16ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 29/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 30/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 31/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 32/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 33/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 34/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 35/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9999 - loss: 0.0031
# Epoch 36/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9999 - loss: 0.0273
# Epoch 37/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 38/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 39/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 40/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 41/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 42/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 43/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 44/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 45/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9999 - loss: 0.0029
# Epoch 46/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 1.0000 - loss: 0.0343
# Epoch 47/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 48/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 49/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 50/50
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 1.0000 - loss: 0.0016

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 2, 256)         │        33,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 2, 256)         │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 100)            │       142,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         6,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 131)            │         8,515 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,756,667 (6.70 MB)
#  Trainable params: 585,555 (2.23 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,171,112 (4.47 MB)

# %%
seed_text = "Fun isn't"

# %%
word_index = {}
for key, value in tokenizer.word_index.items():
    word_index[value] = key

# %%
pred_text = seed_text

# %%
for _ in range(20):
    seed_seq = np.array(tokenizer.texts_to_sequences([seed_text]))
    seed_seq = seed_seq.reshape(seed_seq.shape[0],seed_seq.shape[-1],1)
    pred = np.argmax(model.predict(seed_seq))
    if pred in tokenizer.word_index.values():
        seed_text += " " + word_index[pred]
        pred_text += " " + word_index[pred]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step

# %%
pred_text
# Out:
# "Fun isn't something something something considers considers often disappointing disappointing disappointing considers often disappointing disappointing disappointing disappointing considers often disappointing disappointing disappointing"
